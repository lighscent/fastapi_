# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
vals = np.random.randint(0, 10, 100)
print(vals.shape)
plt.plot(vals, c='b')
plt.plot(np.arange(vals.size), vals, c="r", alpha=0.5)
plt.scatter(np.arange(vals.size), vals)
# Out:
# (100,)
